# %% [markdown]
# name: lcms_data_processing
# date: 08/20/2024
# version: 1.0
# author: Justin Sankey
#
# description: Quick fix for error in IPS Area of Old Method for PFHxA, PFHpA, PFOA, PFNA, and HFPO-DA. Takes raw liquid chromatography mass spectroscopy (LCMS) data, extracts relevant paramters for analysis and writes them to excel.

# %% [markdown]
# When you execute the notebook for the first time you need to install all required python packages.
# So, type the following commands in your python console or anaconda prompt:
# - pip install pandas
# - pip install numpy

# %%
# import all needed packages
import pandas as pd
import numpy as np
from openpyxl import load_workbook

# %% [markdown]
# This is the only cell that you should have to make edits to.
# Enter in your desired input and output file paths
# and change what you deem to be an acceptable recovery range.
# 'Enter in your file as the .txt form generated from the processing station'
# 'Give the desired file path to the folder you want the output file to generate in and then give it a unique name'

# %%
# raw data upload file path
raw_filepath = r'C:\Users\jhsan\OneDrive\Desktop\ACF_Project\Raw_Data\20240903_pfas_kynol_ks_single_compound.txt'

# processed data output file path
processed_filepath =r'C:\Users\jhsan\OneDrive\Desktop\ACF_Project\Processed_Data\20240903_pfas_kynol_ks_single_compound_recoveries.xlsx'

#color-coding for recoveries table(enter in your acceptable good ranges here ie. in range .6-1.4, out of range, <.4 and >1.8 with .4-.6 and 1.4-1.8 being questionable)
in_range = 'background-color: green'
in_range_min_val = 0.6 
in_range_max_val = 1.4
out_range = 'background-color: red'
out_range_min_val = 0.4 
out_range_max_val = 1.8
question_range = 'background-color: yellow'

# %%
# Load data file and remove calibration data
data = pd.read_csv(raw_filepath, delimiter='\t', encoding = 'utf-8',low_memory=False, header=0,)
# Step 1: Replace 'Component Group Name' values
data['Component Group Name'] = data['Component Group Name'].replace('IPS-13C2_PFOA', 'IPS-13C4_PFOA')

# Step 2: Find rows where 'Component Group Name' is 'IPS-13C4_PFOA' (after replacement)
mask = data['Component Group Name'] == 'IPS-13C4_PFOA'

# Step 3: Iterate through each of these rows
for idx, row in data[mask].iterrows():
    sample_name = row['Sample Name']
    
    # Find the corresponding row with 'Component Name' == 'IPS-13C4_PFOA' and the same 'Sample Name'
    matching_row = data[(data['Component Name'] == 'IPS-13C4_PFOA') & (data['Sample Name'] == sample_name)]
    
    if not matching_row.empty:
        # Update the 'Area IPS' with the value from 'Area' in the matching row
        data.at[idx, 'Area IPS'] = matching_row['Area'].values[0]
data_calibration_excluded = data[(data['Sample Type'] != 'Standard')].copy()
data_calibration = data[data['Sample Type']=='Standard']
pd.set_option('display.max_rows', None)  # Show all rows
pd.set_option('display.max_columns', None)  # Show all columns
pd.set_option('display.max_colwidth', None)  # Show full width of columns

# %%
#Area IDA values for IDA components
selected_columns_area = ['Sample Name', 'Sample Index','Acquisition Date & Time','Component Name', 'Area IDA']
area_ida = data_calibration_excluded[selected_columns_area]
area_ida = area_ida[area_ida['Component Name'].str.contains('IDA')]
area_ida.loc[:,'Sample Name Date'] = area_ida['Sample Name'].astype(str) + "_" + area_ida['Acquisition Date & Time']

# Create pivot table with Sample name as the index, component name as the column headers, and area as the values
area_ida_piv = area_ida.pivot_table(index=('Sample Name Date',), columns='Component Name', values='Area IDA', aggfunc='first')

# %%
#Calibration Area IDA Average for IDA components
selected_columns_area = ['Sample Name', 'Sample Index','Acquisition Date & Time','Component Name', 'Area IDA']
cal_area_ida = data_calibration[selected_columns_area]
cal_area_ida = cal_area_ida[cal_area_ida['Component Name'].str.contains('IDA')]
cal_area_ida.loc[:,'Sample Name Date'] = cal_area_ida['Sample Name'].astype(str) + "_" + cal_area_ida['Acquisition Date & Time']

# Create pivot table with Sample name as the index, component name as the column headers, and area as the values
cal_area_ida_piv = cal_area_ida.pivot_table(index=('Sample Name Date',), columns='Component Name', values='Area IDA', aggfunc='first')
#Establishes a row with average of each column
mean_cal = cal_area_ida_piv.mean(numeric_only=True)
mean_cal=pd.DataFrame(mean_cal).T
mean_cal.index=['Average']
cal_area_ida_piv = pd.concat([cal_area_ida_piv,mean_cal])

# %%
#IPS Area Values for IDA components
selected_columns_area = ['Sample Name', 'Sample Index','Acquisition Date & Time','Component Name', 'Area IPS']
area_ips = data_calibration_excluded[selected_columns_area]
area_ips = area_ips[area_ips['Component Name'].str.contains('IDA')]
area_ips.loc[:,'Sample Name Date'] = area_ips['Sample Name'].astype(str) + "_" + area_ips['Acquisition Date & Time']

# Create pivot table with Sample name as the index, component name as the column headers, and area as the values
area_ips_piv = area_ips.pivot_table(index=('Sample Name Date',), columns='Component Name', values='Area IPS', aggfunc='first')

# %%
#IPS Calibration Area and Average for IDA components
selected_columns_area = ['Sample Name', 'Sample Index','Acquisition Date & Time','Component Name', 'Area IPS']
cal_area_ips = data_calibration[selected_columns_area]
cal_area_ips = cal_area_ips[cal_area_ips['Component Name'].str.contains('IDA')]
cal_area_ips.loc[:,'Sample Name Date'] = cal_area_ips['Sample Name'].astype(str) + "_" + cal_area_ida['Acquisition Date & Time']

# Create pivot table with Sample name as the index, component name as the column headers, and area as the values
cal_area_ips_piv = cal_area_ips.pivot_table(index=('Sample Name Date',), columns='Component Name', values='Area IPS', aggfunc='first')
#establishes mean for each column
mean_cal = cal_area_ips_piv.mean(numeric_only=True)
mean_cal=pd.DataFrame(mean_cal).T
mean_cal.index=['Average']
cal_area_ips_piv = pd.concat([cal_area_ips_piv,mean_cal])

# %%
#calibration IDA/IPS ratio
cal_ida_ips_ratio = cal_area_ida_piv.loc['Average']/cal_area_ips_piv.loc['Average']
cal_ida_ips_ratio
#Sample IDA/IPS Ratio
sample_ida_ips_ratio = area_ida_piv/area_ips_piv

# %%
#IPS normalized recoveries to calibration data
ips_norm_recovery = sample_ida_ips_ratio/cal_ida_ips_ratio
ips_norm_recovery
# color code recoveries
def color_map(val):
    if in_range_min_val <= val <= in_range_max_val:
        return in_range
    elif val < out_range_min_val or val > out_range_max_val:
        return out_range
    else:
        return question_range

# Apply the style function to the entire DataFrame
styled_ips_norm_recovery = ips_norm_recovery.style.applymap(color_map)
styled_ips_norm_recovery
# Out:
# <style type="text/css">
# #T_692bf_row0_col0, #T_692bf_row0_col1, #T_692bf_row0_col2, #T_692bf_row0_col5, #T_692bf_row0_col6, #T_692bf_row0_col7, #T_692bf_row0_col8, #T_692bf_row0_col9, #T_692bf_row0_col10, #T_692bf_row0_col11, #T_692bf_row0_col15, #T_692bf_row0_col16, #T_692bf_row0_col17, #T_692bf_row0_col20, #T_692bf_row0_col21, #T_692bf_row1_col0, #T_692bf_row1_col2, #T_692bf_row1_col5, #T_692bf_row1_col6, #T_692bf_row1_col7, #T_692bf_row1_col8, #T_692bf_row1_col9, #T_692bf_row1_col10, #T_692bf_row1_col11, #T_692bf_row1_col14, #T_692bf_row1_col15, #T_692bf_row1_col16, #T_692bf_row1_col17, #T_692bf_row1_col20, #T_692bf_row1_col21, #T_692bf_row2_col5, #T_692bf_row2_col8, #T_692bf_row2_col9, #T_692bf_row2_col10, #T_692bf_row2_col11, #T_692bf_row2_col14, #T_692bf_row2_col15, #T_692bf_row2_col16, #T_692bf_row2_col17, #T_692bf_row2_col20, #T_692bf_row2_col21, #T_692bf_row3_col2, #T_692bf_row3_col5, #T_692bf_row3_col7, #T_692bf_row3_col8, #T_692bf_row3_col9, #T_692bf_row3_col10, #T_692bf_row3_col11, #T_692bf_row3_col14, #T_692bf_row3_col15, #T_692bf_row3_col16, #T_692bf_row3_col20, #T_692bf_row3_col21, #T_692bf_row4_col5, #T_692bf_row4_col6, #T_692bf_row4_col7, #T_692bf_row4_col8, #T_692bf_row4_col9, #T_692bf_row4_col10, #T_692bf_row4_col11, #T_692bf_row4_col14, #T_692bf_row4_col15, #T_692bf_row4_col16, #T_692bf_row4_col17, #T_692bf_row4_col20, #T_692bf_row4_col21, #T_692bf_row5_col5, #T_692bf_row5_col6, #T_692bf_row5_col7, #T_692bf_row5_col8, #T_692bf_row5_col9, #T_692bf_row5_col10, #T_692bf_row5_col11, #T_692bf_row5_col14, #T_692bf_row5_col15, #T_692bf_row5_col16, #T_692bf_row5_col17, #T_692bf_row5_col20, #T_692bf_row5_col21, #T_692bf_row6_col0, #T_692bf_row6_col2, #T_692bf_row6_col5, #T_692bf_row6_col6, #T_692bf_row6_col7, #T_692bf_row6_col8, #T_692bf_row6_col9, #T_692bf_row6_col10, #T_692bf_row6_col11, #T_692bf_row6_col12, #T_692bf_row6_col15, #T_692bf_row6_col16, #T_692bf_row6_col17, #T_692bf_row6_col21, #T_692bf_row7_col0, #T_692bf_row7_col5, #T_692bf_row7_col6, #T_692bf_row7_col7, #T_692bf_row7_col8, #T_692bf_row7_col9, #T_692bf_row7_col10, #T_692bf_row7_col11, #T_692bf_row7_col14, #T_692bf_row7_col15, #T_692bf_row7_col16, #T_692bf_row7_col17, #T_692bf_row7_col20, #T_692bf_row7_col21, #T_692bf_row8_col5, #T_692bf_row8_col8, #T_692bf_row8_col9, #T_692bf_row8_col10, #T_692bf_row8_col11, #T_692bf_row8_col14, #T_692bf_row8_col15, #T_692bf_row8_col16, #T_692bf_row8_col17, #T_692bf_row8_col20, #T_692bf_row8_col21, #T_692bf_row9_col0, #T_692bf_row9_col1, #T_692bf_row9_col2, #T_692bf_row9_col6, #T_692bf_row9_col7, #T_692bf_row9_col8, #T_692bf_row9_col11, #T_692bf_row9_col13, #T_692bf_row9_col14, #T_692bf_row9_col16, #T_692bf_row9_col20, #T_692bf_row9_col21, #T_692bf_row10_col0, #T_692bf_row10_col3, #T_692bf_row10_col6, #T_692bf_row10_col7, #T_692bf_row10_col8, #T_692bf_row10_col11, #T_692bf_row10_col13, #T_692bf_row10_col14, #T_692bf_row10_col15, #T_692bf_row10_col16, #T_692bf_row10_col17, #T_692bf_row11_col1, #T_692bf_row11_col2, #T_692bf_row11_col3, #T_692bf_row11_col5, #T_692bf_row11_col6, #T_692bf_row11_col7, #T_692bf_row11_col8, #T_692bf_row11_col9, #T_692bf_row11_col10, #T_692bf_row11_col11, #T_692bf_row11_col12, #T_692bf_row11_col13, #T_692bf_row11_col14, #T_692bf_row11_col15, #T_692bf_row11_col16, #T_692bf_row11_col17, #T_692bf_row11_col20, #T_692bf_row11_col21, #T_692bf_row12_col0, #T_692bf_row12_col1, #T_692bf_row12_col2, #T_692bf_row12_col3, #T_692bf_row12_col5, #T_692bf_row12_col6, #T_692bf_row12_col7, #T_692bf_row12_col8, #T_692bf_row12_col9, #T_692bf_row12_col10, #T_692bf_row12_col11, #T_692bf_row12_col12, #T_692bf_row12_col13, #T_692bf_row12_col14, #T_692bf_row12_col15, #T_692bf_row12_col16, #T_692bf_row12_col17, #T_692bf_row12_col20, #T_692bf_row12_col21, #T_692bf_row13_col0, #T_692bf_row13_col1, #T_692bf_row14_col0, #T_692bf_row15_col4, #T_692bf_row15_col19, #T_692bf_row16_col4, #T_692bf_row16_col19, #T_692bf_row19_col4, #T_692bf_row19_col19, #T_692bf_row20_col4, #T_692bf_row20_col19, #T_692bf_row22_col0, #T_692bf_row23_col0, #T_692bf_row23 ...

# %%
#Reported Recovery Pivot Table
selected_columns_area = ['Sample Name', 'Sample Index','Acquisition Date & Time','Component Name', 'Reported Recovery']
reported_recovery = data_calibration_excluded[selected_columns_area]
reported_recovery = reported_recovery[reported_recovery['Component Name'].str.contains('IDA')]
reported_recovery.loc[:,'Sample Name Date'] = reported_recovery['Sample Name'].astype(str) + "_" + reported_recovery['Acquisition Date & Time']

# Create pivot table with Sample name as the index, component name as the column headers, and area as the values
reported_recovery_piv = reported_recovery.pivot_table(index=('Sample Name Date',), columns='Component Name', values='Reported Recovery', aggfunc='first')
reported_recovery_piv=reported_recovery_piv/100

# %%
#Color map of Reported recoveries
styled_reported_recovery = reported_recovery_piv.style.applymap(color_map)
styled_reported_recovery
# Out:
# <style type="text/css">
# #T_ca7a5_row0_col0, #T_ca7a5_row0_col1, #T_ca7a5_row0_col2, #T_ca7a5_row0_col5, #T_ca7a5_row0_col6, #T_ca7a5_row0_col7, #T_ca7a5_row0_col8, #T_ca7a5_row0_col9, #T_ca7a5_row0_col11, #T_ca7a5_row0_col12, #T_ca7a5_row0_col15, #T_ca7a5_row0_col16, #T_ca7a5_row0_col17, #T_ca7a5_row0_col20, #T_ca7a5_row0_col21, #T_ca7a5_row1_col0, #T_ca7a5_row1_col2, #T_ca7a5_row1_col5, #T_ca7a5_row1_col6, #T_ca7a5_row1_col7, #T_ca7a5_row1_col8, #T_ca7a5_row1_col9, #T_ca7a5_row1_col11, #T_ca7a5_row1_col12, #T_ca7a5_row1_col14, #T_ca7a5_row1_col15, #T_ca7a5_row1_col16, #T_ca7a5_row1_col17, #T_ca7a5_row1_col20, #T_ca7a5_row1_col21, #T_ca7a5_row2_col5, #T_ca7a5_row2_col8, #T_ca7a5_row2_col9, #T_ca7a5_row2_col11, #T_ca7a5_row2_col14, #T_ca7a5_row2_col15, #T_ca7a5_row2_col16, #T_ca7a5_row2_col17, #T_ca7a5_row2_col20, #T_ca7a5_row2_col21, #T_ca7a5_row3_col2, #T_ca7a5_row3_col5, #T_ca7a5_row3_col7, #T_ca7a5_row3_col8, #T_ca7a5_row3_col9, #T_ca7a5_row3_col11, #T_ca7a5_row3_col14, #T_ca7a5_row3_col15, #T_ca7a5_row3_col16, #T_ca7a5_row3_col17, #T_ca7a5_row3_col20, #T_ca7a5_row3_col21, #T_ca7a5_row4_col5, #T_ca7a5_row4_col6, #T_ca7a5_row4_col7, #T_ca7a5_row4_col8, #T_ca7a5_row4_col9, #T_ca7a5_row4_col11, #T_ca7a5_row4_col12, #T_ca7a5_row4_col14, #T_ca7a5_row4_col15, #T_ca7a5_row4_col16, #T_ca7a5_row4_col17, #T_ca7a5_row4_col20, #T_ca7a5_row4_col21, #T_ca7a5_row5_col5, #T_ca7a5_row5_col6, #T_ca7a5_row5_col7, #T_ca7a5_row5_col8, #T_ca7a5_row5_col9, #T_ca7a5_row5_col11, #T_ca7a5_row5_col12, #T_ca7a5_row5_col14, #T_ca7a5_row5_col15, #T_ca7a5_row5_col16, #T_ca7a5_row5_col17, #T_ca7a5_row5_col20, #T_ca7a5_row5_col21, #T_ca7a5_row6_col0, #T_ca7a5_row6_col2, #T_ca7a5_row6_col5, #T_ca7a5_row6_col6, #T_ca7a5_row6_col7, #T_ca7a5_row6_col8, #T_ca7a5_row6_col9, #T_ca7a5_row6_col11, #T_ca7a5_row6_col12, #T_ca7a5_row6_col15, #T_ca7a5_row6_col16, #T_ca7a5_row6_col17, #T_ca7a5_row6_col21, #T_ca7a5_row7_col0, #T_ca7a5_row7_col5, #T_ca7a5_row7_col6, #T_ca7a5_row7_col7, #T_ca7a5_row7_col8, #T_ca7a5_row7_col9, #T_ca7a5_row7_col11, #T_ca7a5_row7_col12, #T_ca7a5_row7_col14, #T_ca7a5_row7_col15, #T_ca7a5_row7_col16, #T_ca7a5_row7_col17, #T_ca7a5_row7_col20, #T_ca7a5_row7_col21, #T_ca7a5_row8_col5, #T_ca7a5_row8_col8, #T_ca7a5_row8_col9, #T_ca7a5_row8_col10, #T_ca7a5_row8_col11, #T_ca7a5_row8_col14, #T_ca7a5_row8_col15, #T_ca7a5_row8_col16, #T_ca7a5_row8_col17, #T_ca7a5_row8_col20, #T_ca7a5_row8_col21, #T_ca7a5_row9_col0, #T_ca7a5_row9_col1, #T_ca7a5_row9_col2, #T_ca7a5_row9_col4, #T_ca7a5_row9_col5, #T_ca7a5_row9_col6, #T_ca7a5_row9_col7, #T_ca7a5_row9_col8, #T_ca7a5_row9_col9, #T_ca7a5_row9_col11, #T_ca7a5_row9_col14, #T_ca7a5_row9_col15, #T_ca7a5_row9_col16, #T_ca7a5_row9_col17, #T_ca7a5_row9_col20, #T_ca7a5_row9_col21, #T_ca7a5_row10_col0, #T_ca7a5_row10_col3, #T_ca7a5_row10_col4, #T_ca7a5_row10_col6, #T_ca7a5_row10_col7, #T_ca7a5_row10_col8, #T_ca7a5_row10_col9, #T_ca7a5_row10_col11, #T_ca7a5_row10_col12, #T_ca7a5_row10_col13, #T_ca7a5_row10_col14, #T_ca7a5_row10_col15, #T_ca7a5_row10_col16, #T_ca7a5_row10_col17, #T_ca7a5_row11_col1, #T_ca7a5_row11_col2, #T_ca7a5_row11_col3, #T_ca7a5_row11_col5, #T_ca7a5_row11_col6, #T_ca7a5_row11_col7, #T_ca7a5_row11_col8, #T_ca7a5_row11_col9, #T_ca7a5_row11_col10, #T_ca7a5_row11_col11, #T_ca7a5_row11_col12, #T_ca7a5_row11_col13, #T_ca7a5_row11_col14, #T_ca7a5_row11_col15, #T_ca7a5_row11_col16, #T_ca7a5_row11_col17, #T_ca7a5_row11_col20, #T_ca7a5_row11_col21, #T_ca7a5_row12_col0, #T_ca7a5_row12_col1, #T_ca7a5_row12_col2, #T_ca7a5_row12_col3, #T_ca7a5_row12_col5, #T_ca7a5_row12_col6, #T_ca7a5_row12_col7, #T_ca7a5_row12_col8, #T_ca7a5_row12_col9, #T_ca7a5_row12_col10, #T_ca7a5_row12_col11, #T_ca7a5_row12_col12, #T_ca7a5_row12_col13, #T_ca7a5_row12_col14, #T_ca7a5_row12_col15, #T_ca7a5_row12_col16, #T_ca7a5_row12_col17, #T_ca7a5_row12_col20, #T_ca7a5_row12_col21, #T_ca7a5_row13_col0, #T_ca7a5_row13_col1, #T_ca7a5_row13_col3, #T_ca7a5_row13_col4, #T_ca7a5_row13_col5, #T_ca7a5_row13_col9, #T_ca7a5_row13_col12, #T_ca7a5_row13_col13, #T_ca7a5_row13_col ...

# %% [markdown]
# Writes all relevant data to excel file and adds calibration curves.

# %%
# create excel with pandas excelwriter
with pd.ExcelWriter(processed_filepath, engine='openpyxl') as writer:
    styled_ips_norm_recovery.to_excel(writer, sheet_name = 'Calculated Recoveries')
    styled_reported_recovery.to_excel(writer, sheet_name = 'Reported Recoveries')
workbook = load_workbook(processed_filepath)
workbook.save(processed_filepath)
